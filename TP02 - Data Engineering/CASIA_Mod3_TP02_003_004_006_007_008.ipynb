-- %% [markdown]
-- 3. Création d'un workflow
--     --> Création d'un workflow dans "Jobs & Pipelines"
-- 6. Compléter le workflow
--     --> Cf workflow dans "Jobs & Pipelines"
-- 7. Partage de la couche gold
--
-- 8. Configuration de la sécurité
--     --> Accès octroyés

-- %% [markdown]
-- 4. Notebook de test

-- %%
SELECT *
FROM ngow_lakehouse.silver.sales_order_detail
ORDER BY sales_order_id, _tf_valid_from

-- %%
SELECT* FROM ngow_lakehouse.gold.dim_product_category;
