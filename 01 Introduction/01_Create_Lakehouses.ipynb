-- %%
%sql
/* Find the managed location under Catalog >> dbw_<name>_dataplatform_dev_001 >> Details >> Storage root*/
CREATE CATALOG IF NOT EXISTS ngow_lakehouse MANAGED LOCATION 'abfss://unity-catalog-storage@dbstorageyr6wlfzmokxsg.dfs.core.windows.net/7405608140859470';
