-- %%
/*
(Bonus) Connecter Power BI :
Après avoir terminé le Data
Engineering Challenge, connectez
Power Bi Desktop au data model dans
la couche Gold.
*/
-- 1 Ouvre ton catalogue Gold
-- 2 Clique sur le bouton Explorer
-- 3 En haut → clique sur “SQL Warehouse” (ou “Compute → SQL Warehouse”)
-- 4 Ouvre ton SQL Warehouse (important : Power BI ne se connecte qu’à un SQL Warehouse)
-- 5 Clique sur Connection details
--    Server hostname
--    Port (toujours 443)
--    HTTP Path
